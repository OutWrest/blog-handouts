# %%
import json
import random

import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision

# %%
# Make notebook's output stable & reproducible across runs

torch.manual_seed(0)
np.random.seed(0)
random.seed(0)

# %%
label_mappings = json.load(open('../data/imagenet_class_index.json'))
label_mappings = {int(k): v for k, v in label_mappings.items()}

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
        self.model = torchvision.models.resnet18(weights=torchvision.models.ResNet18_Weights.DEFAULT)
        self.normalize = torchvision.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    def forward(self, x):
        # input shape: (batch_size, 3, 224, 224)
        # output shape: (batch_size, 1000)

        x = self.normalize(x)
        x = self.model(x)
        return x

    @staticmethod
    def format_predict(pred):
        pred = pred.squeeze()
        pred = pred.detach().cpu().numpy()
        
        most_likely_idx = pred.argmax()
        confidence = pred[most_likely_idx]
        pred_str = "\"{}\" with {:.2f}% confidence".format(label_mappings[most_likely_idx], confidence * 100)

        return label_mappings[most_likely_idx], confidence, pred_str

def get_image_prediction(image):
    tensor_img = torch.tensor(image, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0)
    tensor_img /= 255.0
    output = model(tensor_img)
    output = F.softmax(output, dim=1)
    _, _, prediction_text = Net.format_predict(output)
    return prediction_text

# %%
model = Net()
model = model.eval()

# %%
print("A picture of my bird:")

burb_img = cv2.imread('../data/burb.png')[..., ::-1]
burb_img = cv2.resize(burb_img, (224, 224))

prediction_text = get_image_prediction(burb_img)

plt.imshow(burb_img)
plt.title(prediction_text)
plt.show()
# Out:
# A picture of my bird:

# %%
white_img = np.ones((224, 224, 3), dtype=np.uint8) * 255
black_img = np.zeros((224, 224, 3), dtype=np.uint8)
random_img = np.random.randint(0, 255, (224, 224, 3), dtype=np.uint8)

predictions = [ get_image_prediction(img) for img in [white_img, black_img, random_img] ]
print(predictions)

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
for i, img in enumerate([white_img, black_img, random_img]):
    ax[i].imshow(img)
    ax[i].set_title(predictions[i])
    ax[i].axis('off')
    ax[i].title.set_fontsize(8)
# Out:
# ['"corkscrew, bottle screw" with 1.86% confidence', '"matchstick" with 9.36% confidence', '"jellyfish" with 26.49% confidence']

# %% [markdown]
# # Goal
# Created a adversarial input that would produce a desired output.
#
# Lets pick a simple target, index `0` of output vector. In this case it should map to `tench, Tinca tinca`

# %% [markdown]
# ## Initial Solution
#
# We will first try a naive soluton, we can use usual machine learning methods to optimize a "bad" guess into a "good" guess.
#
# In this solution we will take an all white image and use stochastic gradient descent to optimize for the target class.

# %%
# starting with a white image, our goal is to calculate the error of the model's prediction to the target class
target_output = torch.tensor([0], dtype=torch.long)

# convert the white image to a tensor and normalize it to the same range as the model's input (0-1)
x = torch.tensor(white_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0
x.requires_grad = True # allow gradients to be calculated since we want to optimize the image

lr = 1. # learning rate

for iteration in range(15):
    output = model(x)

    # our objective is to maximize the probability of the target class
    # so we'll minimize the negative log probability of the target class
    loss = F.cross_entropy(output, target_output)

    # calculate the gradient of the loss with respect to the input image
    # we don't want to update the model's weights, only the image
    model.zero_grad()
    loss.backward()

    # apply gradient descent to the image, this step is usually done by the optimizer
    # but we're doing it manually here, by taking the gradient of the image and updating it
    x.data -= lr * x.grad

    # zero the gradient for the next iteration
    x.grad.zero_()

    # clamp the image to the valid pixel range [0, 1]
    x.data = torch.clamp(x.data, 0, 1)


    # in order to get the most accurate prediction, we need to convert the image back to the original format
    # this means converting image to 0-255 integer instead of 0-1 float, we'll lose some precision but it will
    # give us the actual answer to our question, which is to generate an image that the model predicts as the target class
    current_img = (x.squeeze().detach().cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)

    prediction_text = get_image_prediction(current_img)
    print(f"Iteration: {iteration: <2} | Loss: {loss.item(): .4f} | Prediction:", prediction_text)
# Out:
# Iteration: 0  | Loss:  7.5425 | Prediction: "window shade" with 5.05% confidence
# Iteration: 1  | Loss:  9.2704 | Prediction: "dishrag, dishcloth" with 3.04% confidence
# Iteration: 2  | Loss:  10.1515 | Prediction: "nematode, nematode worm, roundworm" with 1.45% confidence
# Iteration: 3  | Loss:  7.6952 | Prediction: "brain coral" with 2.15% confidence
# Iteration: 4  | Loss:  5.4389 | Prediction: "American alligator, Alligator mississipiensis" with 1.96% confidence
# Iteration: 5  | Loss:  4.7709 | Prediction: "American alligator, Alligator mississipiensis" with 5.01% confidence
# Iteration: 6  | Loss:  3.2306 | Prediction: "tench, Tinca tinca" with 10.06% confidence
# Iteration: 7  | Loss:  2.2304 | Prediction: "brain coral" with 17.83% confidence
# Iteration: 8  | Loss:  2.4371 | Prediction: "tench, Tinca tinca" with 35.66% confidence
# Iteration: 9  | Loss:  1.0132 | Prediction: "tench, Tinca tinca" with 96.03% confidence
# Iteration: 10 | Loss:  0.0390 | Prediction: "tench, Tinca tinca" with 99.90% confidence
# Iteration: 11 | Loss:  0.0015 | Prediction: "tench, Tinca tinca" with 99.92% confidence
# Iteration: 12 | Loss:  0.0013 | Prediction: "tench, Tinca tinca" with 99.93% confidence
# Iteration: 13 | Loss:  0.0012 | Prediction: "tench, Tinca tinca" with 99.93% confidence
# Iteration: 14 | Loss:  0.0011 | Prediction: "tench, Tinca tinca" with 99.94% confidence

# %% [markdown]
# It worked! Lets take a look at the results

# %% [markdown]
# #### What does our image look like?

# %%
plt.imshow(current_img)
plt.title(prediction_text)
plt.show()

# %% [markdown]
# #### How different is the image from the original white image?

# %%
diff = np.abs(white_img - current_img)
max_diff, mean_diff, min_diff = diff.max(), diff.mean(), diff.min()

print(f"Max difference:  {max_diff:.2f}")
print(f"Mean difference: {mean_diff:.2f}")
print(f"Min difference:  {min_diff:.2f}")
# Out:
# Max difference:  209.00
# Mean difference: 14.36
# Min difference:  0.00

# %% [markdown]
# There is a large difference... can we do better?

# %% [markdown]
# ### Optimizing for target class & low difference
#
# Seeing as there's a very large visual difference between a white image and the output image we got, lets try to see if we can still achieve the same target class with a lower difference.
#
# There's a couple of ways we can optimize for this, lets go through a few solutions, taking our previous code as an example

# %%
target_output = torch.tensor([0], dtype=torch.long)

white_img_tensor = torch.tensor(white_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0

x = torch.tensor(white_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0
x.requires_grad = True

lr = 1.

# lets create a new variable, epsilon, to control the amount of difference between the current image and the white image
# this will allow us to control the amount of noise that we add to the image
# for this example lets say we don't want the difference to be more than 10 pixel difference compared to the white image
# we will also divide the epsilon by 255 to normalize it to the same range as the x tensor
epsilon = 10. / 255.

for iteration in range(50):
    output = model(x)

    loss = F.cross_entropy(output, target_output)

    model.zero_grad()
    loss.backward()

    x.data -= lr * x.grad

    x.grad.zero_()

    x.data = torch.clamp(x.data, 0, 1)
    
    # we will also clamp the difference between the current image and the white image
    # this will ensure that the image is always within the valid pixel range
    x.data = torch.clamp(x.data, white_img_tensor - epsilon, white_img_tensor + epsilon)

    current_img = (x.squeeze().detach().cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)

    prediction_text = get_image_prediction(current_img)

    # adding print statements to see the difference between the current image and the white image
    diff = np.abs(white_img - current_img)
    max_diff, mean_diff, min_diff = diff.max(), diff.mean(), diff.min()

    print(
        f"Iteration: {iteration: <2} | Loss: {loss.item(): .4f} | Prediction:", prediction_text,
        f"| Max diff: {max_diff:.2f} | Mean diff: {mean_diff:.2f} | Min diff: {min_diff:.2f}"
    )
# Out:
# Iteration: 0  | Loss:  7.5425 | Prediction: "window shade" with 3.81% confidence | Max diff: 10.00 | Mean diff: 1.39 | Min diff: 0.00
# Iteration: 1  | Loss:  9.1152 | Prediction: "bath towel" with 2.34% confidence | Max diff: 10.00 | Mean diff: 3.73 | Min diff: 0.00
# Iteration: 2  | Loss:  9.4835 | Prediction: "screw" with 3.01% confidence | Max diff: 10.00 | Mean diff: 4.48 | Min diff: 0.00
# Iteration: 3  | Loss:  8.9104 | Prediction: "broom" with 2.33% confidence | Max diff: 10.00 | Mean diff: 4.79 | Min diff: 0.00
# Iteration: 4  | Loss:  8.1987 | Prediction: "whistle" with 2.07% confidence | Max diff: 10.00 | Mean diff: 4.96 | Min diff: 0.00
# Iteration: 5  | Loss:  8.3175 | Prediction: "handkerchief, hankie, hanky, hankey" with 1.93% confidence | Max diff: 10.00 | Mean diff: 5.09 | Min diff: 0.00
# Iteration: 6  | Loss:  7.6980 | Prediction: "handkerchief, hankie, hanky, hankey" with 3.51% confidence | Max diff: 10.00 | Mean diff: 5.15 | Min diff: 0.00
# Iteration: 7  | Loss:  7.8992 | Prediction: "screw" with 1.19% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 8  | Loss:  7.7744 | Prediction: "bath towel" with 15.22% confidence | Max diff: 10.00 | Mean diff: 5.21 | Min diff: 0.00
# Iteration: 9  | Loss:  7.9369 | Prediction: "kite" with 2.65% confidence | Max diff: 10.00 | Mean diff: 5.14 | Min diff: 0.00
# Iteration: 10 | Loss:  9.1638 | Prediction: "nematode, nematode worm, roundworm" with 1.36% confidence | Max diff: 10.00 | Mean diff: 5.23 | Min diff: 0.00
# Iteration: 11 | Loss:  8.3419 | Prediction: "handkerchief, hankie, hanky, hankey" with 1.67% confidence | Max diff: 10.00 | Mean diff: 5.24 | Min diff: 0.00
# Iteration: 12 | Loss:  7.7741 | Prediction: "handkerchief, hankie, hanky, hankey" with 3.49% confidence | Max diff: 10.00 | Mean diff: 5.23 | Min diff: 0.00
# Iteration: 13 | Loss:  7.0480 | Prediction: "poncho" with 2.37% confidence | Max diff: 10.00 | Mean diff: 5.24 | Min diff: 0.00
# Iteration: 14 | Loss:  6.9560 | Prediction: "handkerchief, hankie, hanky, hankey" with 1.86% confidence | Max diff: 10.00 | Mean diff: 5.20 | Min diff: 0.00
# Iteration: 15 | Loss:  8.1059 | Prediction: "handkerchief, hankie, hanky, hankey" with 4.28% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 16 | Loss:  7.4336 | Prediction: "necklace" with 2.18% confidence | Max diff: 10.00 | Mean diff: 5.20 | Min diff: 0.00
# Iteration: 17 | Loss:  8.6376 | Prediction: "handkerchief, hankie, hanky, hankey" with 4.54% confidence | Max diff: 10.00 | Mean diff: 5.18 | Min diff: 0.00
# Iteration: 18 | Loss:  7.7191 | Prediction: "poncho" with 1.58% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 19 | Loss:  7.4852 | Prediction: "handkerchief, hankie, hanky, hankey" with 2.29% confidence | Max diff: 10.00 | Mean diff: 5.22 | Min diff: 0.00
# Iteration: 20 | Loss:  7.4092 | Prediction: "tick" with 1.82% confidence | Max diff: 10.00 | Mean diff: 5.21 | Min diff: 0.00
# Iteration: 21 | Loss:  7.1596 | Prediction: "handkerchief, hankie, hanky, hankey" with 2.60% confidence | Max diff: 10.00 | Mean diff: 5.18 | Min diff: 0.00
# Iteration: 22 | Loss:  6.7118 | Prediction: "tick" with 1.94% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 23 | Loss:  7.9702 | Prediction: "handkerchief, hankie, hanky, hankey" with 1.25% confidence | Max diff: 10.00 | Mean diff: 5.18 | Min diff: 0.00
# Iteration: 24 | Loss:  7.3645 | Prediction: "quill, quill pen" with 2.40% confidence | Max diff: 10.00 | Mean diff: 5.21 | Min diff: 0.00
# Iteration: 25 | Loss:  6.5141 | Prediction: "handkerchief, hankie, hanky, hankey" with 2.05% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 26 | Loss:  7.2955 | Prediction: "handkerchief, hankie, hanky, hankey" with 4.49% confidence | Max diff: 10.00 | Mean diff: 5.18 | Min diff: 0.00
# Iteration: 27 | Loss:  7.0651 | Prediction: "ballpoint, ballpoint pen, ballpen, Biro" with 1.58% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 28 | Loss:  8.1240 | Prediction: "handkerchief, hankie, hanky, hankey" with 7.01% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 29 | Loss:  7.4547 | Prediction: "tick" with 2.29% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 30 | Loss:  8.7279 | Prediction: "fountain pen" with 1.14% confidence | Max diff: 10.00 | Mean diff: 5.21 | Min diff: 0.00
# Iteration: 31 | Loss:  7.8096 | Prediction: "bath towel" with 4.35% confidence | Max diff: 10.00 | Mean diff: 5.22 | Min diff: 0.00
# Iteration: 32 | Loss:  6.2256 | Prediction: "parachute, chute" with 2.74% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 33 | Loss:  8.6671 | Prediction: "handkerchief, hankie, hanky, hankey" with 1.63% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 34 | Loss:  7.3107 | Prediction: "handkerchief, hankie, hanky, hankey" with 2.37% confidence | Max diff: 10.00 | Mean diff: 5.20 | Min diff: 0.00
# Iteration: 35 | Loss:  6.2110 | Prediction: "bath towel" with 2.46% confidence | Max diff: 10.00 | Mean diff: 5.20 | Min diff: 0.00
# Iteration: 36 | Loss:  7.1189 | Prediction: "parachute, chute" with 1.28% confidence | Max diff: 10.00 | Mean diff: 5.21 | Min diff: 0.00
# Iteration: 37 | Loss:  7.0403 | Prediction: "handkerchief, hankie, hanky, hankey" with 5.96% confidence | Max diff: 10.00 | Mean diff: 5.19 | Min diff: 0.00
# Iteration: 38 | Loss:  7.2789 | Prediction: "parachute, chute" with 1.88% confidence | Max diff: 10.00 | Mean diff: 5.13 | Min diff: 0.00
# Iteration: 39 | Loss:  7.9023 | Prediction: "bath towel" with 2.09% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 40 | Loss:  7.6118 | Prediction: "bath towel" with 5.71% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 41 | Loss:  7.2886 | Prediction: "tick" with 1.86% confidence | Max diff: 10.00 | Mean diff: 5.14 | Min diff: 0.00
# Iteration: 42 | Loss:  7.6241 | Prediction: "handkerchief, hankie, hanky, hankey" with 3.72% confidence | Max diff: 10.00 | Mean diff: 5.16 | Min diff: 0.00
# Iteration: 43 | Loss:  6.9315 | Prediction: "tick" with 1.86% confidence | Max diff: 10.00 | Mean diff: 5.15 | Min diff: 0.00
# Iteration: 44 | Loss:  7.6833 | Prediction: "poncho" with 4.03% confidence | Max diff: 10.00 | Mean diff: 5.18 | Min diff: 0.00
# Iteration: 45 | Loss:  6.9814 | Prediction: "tick" with 3.93% confidence | Max diff: 10.00 | Mean diff: 5.17 | Min diff: 0.00
# Iteration: 46 | Loss:  8.1551 | Prediction: "handkerchief, hankie, hanky, hankey" with 4.37% confidence | Max diff: 10.00 | Mean diff: 5.16 | Min diff: 0.00
# Iteration: 47 | Loss:  7.5832 | Prediction: "tick" with 2.52% confidence | Max diff: 10.00 | Mean diff: 5.16 | Min diff: 0.00
# Iteration: 48 | Loss:  7.9615 | Prediction: "handkerchief, hankie, hanky, hankey" with 4.31% confidence | Max diff: 10.00 | Mean diff: 5.16 | Min diff: 0.00
# Iteration: 49 | Loss:  7.4072 | Prediction: "tick" with 1.75% confidence | Max diff: 10.00 | Mean diff: 5.16 | Min diff: 0.00

# %% [markdown]
# Why is our result so bad? Even after 50 iterations we still have a almost same loss as what we started with.
#
# Well we are using a very simple way to update the gradients and it is very prone to *oscillation*. We are also clamping results which is also contributing to the oscillation.
#
# We need to reduce the learning rate.

# %%
target_output = torch.tensor([0], dtype=torch.long)

white_img_tensor = torch.tensor(white_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0

x = torch.tensor(white_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0
x.requires_grad = True

# reduced from 1 to 0.1
lr = 0.1

epsilon = 10. / 255.

for iteration in range(25):
    output = model(x)

    loss = F.cross_entropy(output, target_output)

    model.zero_grad()
    loss.backward()

    x.data -= lr * x.grad

    x.grad.zero_()
    x.data = torch.clamp(x.data, 0, 1)
    x.data = torch.clamp(x.data, white_img_tensor - epsilon, white_img_tensor + epsilon)

    current_img = (x.squeeze().detach().cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    prediction_text = get_image_prediction(current_img)

    diff = np.abs(white_img - current_img)
    max_diff, mean_diff, min_diff = diff.max(), diff.mean(), diff.min()

    print(
        f"Iteration: {iteration: <2} | Loss: {loss.item(): .4f} | Prediction:", prediction_text,
        f"| Max diff: {max_diff:.2f} | Mean diff: {mean_diff:.2f} | Min diff: {min_diff:.2f}"
    )
# Out:
# Iteration: 0  | Loss:  7.5425 | Prediction: "corkscrew, bottle screw" with 1.76% confidence | Max diff: 4.00 | Mean diff: 0.51 | Min diff: 0.00
# Iteration: 1  | Loss:  7.4247 | Prediction: "corkscrew, bottle screw" with 1.45% confidence | Max diff: 10.00 | Mean diff: 0.67 | Min diff: 0.00
# Iteration: 2  | Loss:  7.8976 | Prediction: "ski" with 1.38% confidence | Max diff: 10.00 | Mean diff: 0.88 | Min diff: 0.00
# Iteration: 3  | Loss:  7.8823 | Prediction: "ski" with 1.74% confidence | Max diff: 10.00 | Mean diff: 1.11 | Min diff: 0.00
# Iteration: 4  | Loss:  7.5663 | Prediction: "ski" with 2.05% confidence | Max diff: 10.00 | Mean diff: 1.34 | Min diff: 0.00
# Iteration: 5  | Loss:  6.6579 | Prediction: "snowmobile" with 2.57% confidence | Max diff: 10.00 | Mean diff: 1.57 | Min diff: 0.00
# Iteration: 6  | Loss:  6.3951 | Prediction: "envelope" with 3.24% confidence | Max diff: 10.00 | Mean diff: 1.82 | Min diff: 0.00
# Iteration: 7  | Loss:  6.9340 | Prediction: "spider web, spider's web" with 1.73% confidence | Max diff: 10.00 | Mean diff: 2.11 | Min diff: 0.00
# Iteration: 8  | Loss:  6.3351 | Prediction: "whistle" with 4.70% confidence | Max diff: 10.00 | Mean diff: 2.31 | Min diff: 0.00
# Iteration: 9  | Loss:  5.5793 | Prediction: "spider web, spider's web" with 6.55% confidence | Max diff: 10.00 | Mean diff: 2.48 | Min diff: 0.00
# Iteration: 10 | Loss:  5.4742 | Prediction: "tray" with 10.74% confidence | Max diff: 10.00 | Mean diff: 2.64 | Min diff: 0.00
# Iteration: 11 | Loss:  5.0233 | Prediction: "spider web, spider's web" with 5.89% confidence | Max diff: 10.00 | Mean diff: 2.82 | Min diff: 0.00
# Iteration: 12 | Loss:  4.9147 | Prediction: "tray" with 4.78% confidence | Max diff: 10.00 | Mean diff: 2.95 | Min diff: 0.00
# Iteration: 13 | Loss:  3.1300 | Prediction: "envelope" with 3.82% confidence | Max diff: 10.00 | Mean diff: 3.08 | Min diff: 0.00
# Iteration: 14 | Loss:  4.8309 | Prediction: "tench, Tinca tinca" with 5.76% confidence | Max diff: 10.00 | Mean diff: 3.23 | Min diff: 0.00
# Iteration: 15 | Loss:  2.7523 | Prediction: "brain coral" with 8.50% confidence | Max diff: 10.00 | Mean diff: 3.34 | Min diff: 0.00
# Iteration: 16 | Loss:  3.3318 | Prediction: "tench, Tinca tinca" with 4.90% confidence | Max diff: 10.00 | Mean diff: 3.46 | Min diff: 0.00
# Iteration: 17 | Loss:  2.8901 | Prediction: "brain coral" with 10.10% confidence | Max diff: 10.00 | Mean diff: 3.57 | Min diff: 0.00
# Iteration: 18 | Loss:  3.0373 | Prediction: "broom" with 4.58% confidence | Max diff: 10.00 | Mean diff: 3.71 | Min diff: 0.00
# Iteration: 19 | Loss:  3.7803 | Prediction: "tench, Tinca tinca" with 30.13% confidence | Max diff: 10.00 | Mean diff: 3.83 | Min diff: 0.00
# Iteration: 20 | Loss:  1.1454 | Prediction: "tench, Tinca tinca" with 50.96% confidence | Max diff: 10.00 | Mean diff: 3.90 | Min diff: 0.00
# Iteration: 21 | Loss:  0.5941 | Prediction: "tench, Tinca tinca" with 74.24% confidence | Max diff: 10.00 | Mean diff: 3.95 | Min diff: 0.00
# Iteration: 22 | Loss:  0.2818 | Prediction: "tench, Tinca tinca" with 99.14% confidence | Max diff: 10.00 | Mean diff: 3.99 | Min diff: 0.00
# Iteration: 23 | Loss:  0.0085 | Prediction: "tench, Tinca tinca" with 99.76% confidence | Max diff: 10.00 | Mean diff: 4.03 | Min diff: 0.00
# Iteration: 24 | Loss:  0.0051 | Prediction: "tench, Tinca tinca" with 99.81% confidence | Max diff: 10.00 | Mean diff: 4.03 | Min diff: 0.00

# %% [markdown]
# Our model learned! We have max pixel difference of 10 and we are still able to create an adversarial image.
#
# Lets see what this image looks like

# %%
plt.imshow(current_img)
plt.title(prediction_text)
plt.show()

# %% [markdown]
# Compared to an all white image, we can still tell the difference that this image is not like the original one we started with.
#
# But if we started with more of a complex image, we will barely tell the difference.

# %% [markdown]
# ### Adversarial Attack on a Bird Image
#
# Lets try to get the model to classify the bird image to target index `413`, `assault rifle, assault gun`.

# %%
target_output = torch.tensor([413], dtype=torch.long)

burb_img_tensor = torch.tensor(burb_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0

x = torch.tensor(burb_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0
x.requires_grad = True

lr = 0.1

# lets lower the epsilon to a lower pixel difference
epsilon = 1. / 255.

for iteration in range(10):
    output = model(x)

    loss = F.cross_entropy(output, target_output)

    model.zero_grad()
    loss.backward()

    x.data -= lr * x.grad

    x.grad.zero_()
    x.data = torch.clamp(x.data, 0, 1)
    x.data = torch.clamp(x.data, burb_img_tensor - epsilon, burb_img_tensor + epsilon)

    current_img = (x.squeeze().detach().cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    prediction_text = get_image_prediction(current_img)

    # changed types as uint8 underflows when subtracting
    diff = np.abs(burb_img.astype(np.int32) - current_img.astype(np.int32))
    max_diff, mean_diff, min_diff = diff.max(), diff.mean(), diff.min()

    print(
        f"Iteration: {iteration: <2} | Loss: {loss.item(): .4f} | Prediction:", prediction_text,
        f"| Max diff: {max_diff:.2f} | Mean diff: {mean_diff:.2f} | Min diff: {min_diff:.2f}"
    )
# Out:
# Iteration: 0  | Loss:  13.4382 | Prediction: "puffer, pufferfish, blowfish, globefish" with 5.17% confidence | Max diff: 2.00 | Mean diff: 0.76 | Min diff: 0.00
# Iteration: 1  | Loss:  8.1450 | Prediction: "goose" with 6.03% confidence | Max diff: 2.00 | Mean diff: 0.70 | Min diff: 0.00
# Iteration: 2  | Loss:  4.7022 | Prediction: "assault rifle, assault gun" with 4.97% confidence | Max diff: 2.00 | Mean diff: 0.73 | Min diff: 0.00
# Iteration: 3  | Loss:  2.8506 | Prediction: "assault rifle, assault gun" with 15.59% confidence | Max diff: 2.00 | Mean diff: 0.75 | Min diff: 0.00
# Iteration: 4  | Loss:  1.6048 | Prediction: "assault rifle, assault gun" with 24.72% confidence | Max diff: 2.00 | Mean diff: 0.77 | Min diff: 0.00
# Iteration: 5  | Loss:  1.1955 | Prediction: "assault rifle, assault gun" with 64.57% confidence | Max diff: 2.00 | Mean diff: 0.77 | Min diff: 0.00
# Iteration: 6  | Loss:  0.3494 | Prediction: "assault rifle, assault gun" with 88.91% confidence | Max diff: 2.00 | Mean diff: 0.71 | Min diff: 0.00
# Iteration: 7  | Loss:  0.0869 | Prediction: "assault rifle, assault gun" with 88.80% confidence | Max diff: 2.00 | Mean diff: 0.66 | Min diff: 0.00
# Iteration: 8  | Loss:  0.0470 | Prediction: "assault rifle, assault gun" with 90.01% confidence | Max diff: 2.00 | Mean diff: 0.66 | Min diff: 0.00
# Iteration: 9  | Loss:  0.0376 | Prediction: "assault rifle, assault gun" with 91.72% confidence | Max diff: 2.00 | Mean diff: 0.66 | Min diff: 0.00

# %%
delta_img = np.abs(burb_img.astype(np.int32) - current_img.astype(np.int32)).astype(np.uint8)

fig, ax = plt.subplots(1, 3, figsize=(15, 5))
titles = ["Original Image", "Adversarial Image", "Difference Image"]
images = [burb_img, current_img, ~delta_img]

for i in range(3):
    ax[i].imshow(images[i])
    ax[i].set_title(titles[i])
    ax[i].axis('off')

plt.show()

print("Original Image Prediciton:")
print(get_image_prediction(burb_img))

print()

print("Adversarial Image Prediction:")
print(get_image_prediction(current_img))
# Out:
# Original Image Prediciton:
# "goldfinch, Carduelis carduelis" with 62.17% confidence
#
# Adversarial Image Prediction:
# "assault rifle, assault gun" with 91.72% confidence

# %% [markdown]
# ## Fast Gradient Signed Method (FGSM) Solution
#
# Lets modify our code to try to apply FGSM. In this attack, we calculate a gradient based on a loss function to our targeted class, and apply a small epsilon in that the direction of the sign of the gradient.

# %% [markdown]
# $$
# \text{Adversarial example: } X_{\text{adv}} = X + \epsilon \cdot \text{sign}(\nabla_X J(\theta, X, y))
# $$
#
# Where:
# \begin{align*}
# & X_{\text{adv}} \text{ is the adversarial example,} \\
# & X \text{ is the original input image,} \\
# & \epsilon \text{ is the perturbation magnitude,} \\
# & \nabla_X J(\theta, X, y) \text{ is the gradient of the loss function } J \text{ with respect to } X \text{ evaluated at } X, \\
# & \theta \text{ represents the model parameters, and} \\
# & y \text{ is the true label of } X.
# \end{align*}
# $$

# %%
target_output = torch.tensor([0], dtype=torch.long) # we will target index 0, which is "tench, Tinca tinca"

burb_img_tensor = torch.tensor(burb_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0

x = torch.tensor(burb_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0
x.requires_grad = True

epsilon = 2. / 255.

output = model(x)
loss = -F.cross_entropy(output, target_output)

model.zero_grad()
loss.backward()

grad = x.grad.data

x_adv = x + epsilon * grad.sign()
x_adv = torch.clamp(x_adv, 0, 1)

current_img = (x_adv.squeeze().detach().cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
prediction_text = get_image_prediction(current_img)

diff = np.abs(burb_img.astype(np.int32) - current_img.astype(np.int32))
max_diff, mean_diff, min_diff = diff.max(), diff.mean(), diff.min()

print(
    f"Loss: {loss.item(): .4f} | Prediction:", prediction_text,
    f"| Max diff: {max_diff:.2f} | Mean diff: {mean_diff:.2f} | Min diff: {min_diff:.2f}"
)
# Out:
# Loss: -9.0888 | Prediction: "tench, Tinca tinca" with 29.52% confidence | Max diff: 3.00 | Mean diff: 2.00 | Min diff: 0.00

# %% [markdown]
# ### Disclaimer
#
# FGSM does not run any interations and it is sensative to epsilon and input image. Depending on input image & target class, it may FSGM might not be the best method but it is a good start.

# %% [markdown]
# Lets see what the images look like

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
titles = ["Original Image", "Adversarial Image", "Perturbation Image"]
images = [burb_img, current_img, ~diff.astype(np.uint8)]

for i in range(3):
    ax[i].imshow(images[i])
    ax[i].set_title(titles[i])
    ax[i].axis('off')

plt.show()

print("Original Image Prediciton:")
print(get_image_prediction(burb_img))

print()

print("Adversarial Image Prediction:")
print(get_image_prediction(current_img))
# Out:
# Original Image Prediciton:
# "goldfinch, Carduelis carduelis" with 62.17% confidence
#
# Adversarial Image Prediction:
# "tench, Tinca tinca" with 29.52% confidence

# %% [markdown]
# ## Project Gradient Descent (PGD) Solution
#
# Lets modify our code to try to apply PGD. At a high level this attack is basically iterative FGSM. Instead of applying the perturbation once, we will take small steps into the sign of the gradient.

# %% [markdown]
# $$
# \text{Initialize } X^{(0)} = X \text{ and set } t = 0
# $$
#
# Repeat until convergence or maximum iterations:
# $$
# \begin{align*}
# & X^{(t+1)} = \text{Clip}(X^{(t)} + \alpha \cdot \text{sign}(\nabla_X J(\theta, X^{(t)}, y)), \epsilon) \\
# & t = t + 1
# \end{align*}
# $$
#
# Where:
# \begin{align*}
# & X^{(t)} \text{ is the image at iteration } t, \\
# & X \text{ is the original input image,} \\
# & \epsilon \text{ is the perturbation limit,} \\
# & \alpha \text{ is the step size,} \\
# & \text{Clip}(x, \epsilon) \text{ clips } x \text{ to be within } \epsilon \text{ of } X, \\
# & \nabla_X J(\theta, X^{(t)}, y) \text{ is the gradient of the loss function } J \text{ with respect to } X \text{ evaluated at } X^{(t)}, \\
# & \theta \text{ represents the model parameters, and} \\
# & y \text{ is the true label of } X.
# \end{align*}
# $$

# %%
target_output = torch.tensor([413], dtype=torch.long) # we will target index 413, which is "assault rifle, assault gun"

burb_img_tensor = torch.tensor(burb_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0

x = torch.tensor(burb_img, dtype=torch.float32).permute(2, 0, 1).unsqueeze(0) / 255.0
x.requires_grad = True

epsilon =   5. / 255. # we will allow a maximum of 5 pixel difference
alpha =     1. / 255. # step size at each iteration (how many pixels to move each iteration)

for iteration in range(10):
    output = model(x)
    loss = -F.cross_entropy(output, target_output)

    model.zero_grad()
    loss.backward()

    x.data = x.data + alpha * x.grad.sign()
    x.data = torch.clamp(x.data, 0, 1)
    x.data = torch.clamp(x.data, burb_img_tensor - epsilon, burb_img_tensor + epsilon)

    current_img = (x.squeeze().detach().cpu().permute(1, 2, 0).numpy() * 255).astype(np.uint8)
    prediction_text = get_image_prediction(current_img)

    # changed types as uint8 underflows when subtracting
    diff = np.abs(burb_img.astype(np.int32) - current_img.astype(np.int32))
    max_diff, mean_diff, min_diff = diff.max(), diff.mean(), diff.min()

    print(
        f"Iteration: {iteration: <2} | Loss: {loss.item(): .4f} | Prediction:", prediction_text,
        f"| Max diff: {max_diff:.2f} | Mean diff: {mean_diff:.2f} | Min diff: {min_diff:.2f}"
    )
# Out:
# Iteration: 0  | Loss: -13.4382 | Prediction: "puffer, pufferfish, blowfish, globefish" with 5.08% confidence | Max diff: 2.00 | Mean diff: 1.00 | Min diff: 0.00
# Iteration: 1  | Loss: -8.0757 | Prediction: "muzzle" with 3.38% confidence | Max diff: 3.00 | Mean diff: 1.75 | Min diff: 0.00
# Iteration: 2  | Loss: -4.8234 | Prediction: "assault rifle, assault gun" with 15.30% confidence | Max diff: 3.00 | Mean diff: 2.55 | Min diff: 0.00
# Iteration: 3  | Loss: -1.8669 | Prediction: "assault rifle, assault gun" with 68.43% confidence | Max diff: 4.00 | Mean diff: 3.22 | Min diff: 0.00
# Iteration: 4  | Loss: -0.3802 | Prediction: "assault rifle, assault gun" with 84.15% confidence | Max diff: 5.00 | Mean diff: 4.04 | Min diff: 0.00
# Iteration: 5  | Loss: -0.1732 | Prediction: "assault rifle, assault gun" with 90.14% confidence | Max diff: 6.00 | Mean diff: 4.18 | Min diff: 0.00
# Iteration: 6  | Loss: -0.1038 | Prediction: "assault rifle, assault gun" with 92.51% confidence | Max diff: 6.00 | Mean diff: 4.42 | Min diff: 0.00
# Iteration: 7  | Loss: -0.0781 | Prediction: "assault rifle, assault gun" with 94.01% confidence | Max diff: 6.00 | Mean diff: 4.55 | Min diff: 0.00
# Iteration: 8  | Loss: -0.0620 | Prediction: "assault rifle, assault gun" with 95.16% confidence | Max diff: 6.00 | Mean diff: 4.69 | Min diff: 0.00
# Iteration: 9  | Loss: -0.0498 | Prediction: "assault rifle, assault gun" with 96.24% confidence | Max diff: 6.00 | Mean diff: 4.75 | Min diff: 0.00

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
titles = ["Original Image", "Adversarial Image", "Perturbation Image"]
images = [burb_img, current_img, ~diff.astype(np.uint8)]

for i in range(3):
    ax[i].imshow(images[i])
    ax[i].set_title(titles[i])
    ax[i].axis('off')

plt.show()

print("Original Image Prediciton:")
print(get_image_prediction(burb_img))

print()

print("Adversarial Image Prediction:")
print(get_image_prediction(current_img))
# Out:
# Original Image Prediciton:
# "goldfinch, Carduelis carduelis" with 62.17% confidence
#
# Adversarial Image Prediction:
# "assault rifle, assault gun" with 96.24% confidence
